# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SehrishEjaz1/Flyrank_ML_Intern/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing Lane 2: Refresh / Content Opportunity Scoring.
#
# The question is simple:
# Which pages should a content team review first?
# Not every page needs attention, only the ones where effort is most likely
# to matter. This lane lets me build a ranked list using real search signals,
# which is more useful than reviewing pages at random or by gut feeling.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages to review for a content refresh.
#
# Who acts on it: a content editor who checks the ranked list
# and decides what to update or fix.
#
# Cost of getting it wrong:
# - Wrong page flagged: editor wastes time on a page that was fine.
# - Real problem missed: a declining page gets ignored and keeps losing traffic.
#
# Missing a real problem is the bigger cost here.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess
subprocess.run(["git", "clone", "https://github.com/SehrishEjaz1/Flyrank_ML_Intern.git"])
os.chdir("Flyrank_ML_Intern")
print(os.getcwd())

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Total pages
print("Total pages:", len(df))

# How many pages are declining
declining = df["trend_direction"].str.lower().eq("down").mean()
print("Decline rate:", round(declining * 100, 1), "%")

# Stale but still visible pages
stale = (df["impressions_90d"] >= 500) & (df["days_since_last_update"] >= 180)
print("Stale visible pages:", stale.sum())
# Out:
# /content/Flyrank_ML_Intern/Flyrank_ML_Intern
# Total pages: 30000
# Decline rate: 54.2 %
# Stale visible pages: 17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can say:
# - Some pages show patterns that are linked to declining traffic —
#   this is observed, not proven.
# - A model can rank these pages better than a simple hand rule —
#   shown by Precision@50 on this dataset.
# - The output is a ranked list to help a human decide — not an
#   automatic decision.
#
# What I cannot say:
# - That fixing a page will definitely bring traffic back.
# - That I found how Google's algorithm works.
# - That these results will be exactly the same on the full dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
